# %% [markdown]
# # Tweepy - Getting Data from Twitter - Data Science Part Time Cohort 21
#
# * *Description - Phase1 Notebook -Get Data from Twitter*
# * *Author - Jithin J Kumar*
# * *Date - 15-03-2019*

# %%
import json    
tweets = []
for line in open('arsenal.json', 'r'):
    tweets.append(json.loads(line))

# %%
type(tweets)
# Out:
# list

# %%
type(tweets[0])
# Out:
# dict

# %%
tweets[700]
# Out:
# {'created_at': 'Sat Apr 07 08:31:15 +0000 2018',
#  'id': 982536269006860288,
#  'id_str': '982536269006860288',
#  'text': 'RT @HighburyAFCsoul: Seriously Robbie tell them both to calm down how are we supposed to get Wenger Out and our Arsenal back if DT and Clau…',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 882634082710151169,
#   'id_str': '882634082710151169',
#   'name': 'Gooner Navz',
#   'screen_name': 'MrNaveedAFC',
#   'location': 'London, England',
#   'url': None,
#   'description': 'Gooner Forever! @arsenal Season Ticket Holder #Away #Home! #WengerOut #KroenkeOut 🔴⚪️',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 57,
#   'friends_count': 75,
# ...

# %%
tweets[700].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])

# %%
for item in tweets:
    print(item['user'])
# Out:
# {'id': 593433609, 'id_str': '593433609', 'name': 'Edison', 'screen_name': 'Son0fAphrodite_', 'location': None, 'url': None, 'description': 'Go big or go home// COYG', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 138, 'friends_count': 175, 'listed_count': 2, 'favourites_count': 5684, 'statuses_count': 19002, 'created_at': 'Tue May 29 04:25:57 +0000 2012', 'utc_offset': 28800, 'time_zone': 'Beijing', 'geo_enabled': True, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.tw
# ...

# %%
tweets[0]['user']['time_zone']
# Out:
# 'Beijing'
